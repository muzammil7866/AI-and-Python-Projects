# %%
class Stack(object):
    def __init__(self):
        self.arr = []
            
    def isEmpty(self):
        if(len(self.arr) == 0):
            return True
        
        else:
            return False
        
    def push(self,item):
        self.arr.append(item)
            
            
    def pop(self):
        if(self.isEmpty()):
            return []
        else:
            out = self.arr.pop()
            return out
        
    def peek(self):
        if(self.isEmpty()):
            return []
        else:
            return self.arr[len(self.arr)-1]
        
        

class Queue(object):
    def __init__(self):
        self.arr = []
        
    def isEmpty(self):
        if(len(self.arr) == 0):
            return True
        else:
            return False
        
    def enqueue(self, item):
        self.arr.append(item)
        
    def dequeue(self):
        if(not self.isEmpty()):
            temp = self.arr[0]
            self.arr.remove(self.arr[0])
            return temp
        
        else:
            return []
        
    def peek(self):
        if(not self.isEmpty()):
            return self.arr[0]
        
        else:
            return []

# %%
def BFS(startState, goalState):
    node = startState
    if startState == goalState:
        return goalState
    
    frontier = Queue()
    visited = [startState]
    
    while(not frontier.isEmpty()):
        thisNode = frontier.dequeue()
        
        for 
        

start_state_tiles = [
    2, 8, 3, 
    1, 6, 4, 
    7, 0, 5]

goal_state_tiles = [
    1, 2, 3, 
    8, 0, 4,
    7, 6, 5]

BFS(start_state_tiles, goal_state_tiles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 140
#     130 start_state_tiles = [
#     131     2, 8, 3,
#     132     1, 6, 4,
#     133     7, 0, 5]
#     135 goal_state_tiles = [
#     136     1, 2, 3,
#     137     8, 0, 4,
#     138     7, 6, 5]
# --> 140 BFS(start_state_tiles, goal_state_tiles)
#
# Cell In[7], line 115, in BFS(start_state, goal_state)
#     112 while not frontier.is_empty():
#     113     # select a candidate node
#     114     node = frontier.pop()
# --> 115     explored.add(node.state)
#     117     # goal test
#     118     if node.state == goal_state:
#
# TypeError: unhashable type: 'list'
